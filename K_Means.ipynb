# %% [markdown]
# # K-**Means**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('indian_food.csv')
data.head()
# Out:
#              name  ... region
# 0      Balu shahi  ...   East
# 1          Boondi  ...   West
# 2  Gajar ka halwa  ...  North
# 3          Ghevar  ...   West
# 4     Gulab jamun  ...   East
#
# [5 rows x 9 columns]

# %%
data = data.drop(["course","region","cook_time","prep_time"], axis=1)
data.head()
# Out:
#              name  ...        state
# 0      Balu shahi  ...  West Bengal
# 1          Boondi  ...    Rajasthan
# 2  Gajar ka halwa  ...       Punjab
# 3          Ghevar  ...    Rajasthan
# 4     Gulab jamun  ...  West Bengal
#
# [5 rows x 5 columns]

# %%
data_x = data.iloc[:, 1:3]
data_x.head()
# Out:
#                                          ingredients        diet
# 0                    Maida flour, yogurt, oil, sugar  vegetarian
# 1                            Gram flour, ghee, sugar  vegetarian
# 2       Carrots, milk, sugar, ghee, cashews, raisins  vegetarian
# 3  Flour, ghee, kewra, milk, clarified butter, su...  vegetarian
# 4  Milk powder, plain flour, baking powder, ghee,...  vegetarian

# %%
plt.scatter(data.diet, data.ingredients, s=10, c='c', marker='o', alpha=1)
plt.show()

# %%
x_array = np.array(data_x)
print(x_array)
# Out:
# [['Maida flour, yogurt, oil, sugar' 'vegetarian']
#  ['Gram flour, ghee, sugar' 'vegetarian']
#  ['Carrots, milk, sugar, ghee, cashews, raisins' 'vegetarian']
#  ['Flour, ghee, kewra, milk, clarified butter, sugar, almonds, pistachio, saffron, green cardamom'
#   'vegetarian']
#  ['Milk powder, plain flour, baking powder, ghee, milk, sugar, water, rose water'
#   'vegetarian']
#  ['Sugar syrup, lentil flour' 'vegetarian']
#  ['Maida, corn flour, baking soda, vinegar, curd, water, turmeric, saffron, cardamom'
#   'vegetarian']
#  ['Cashews, ghee, cardamom, sugar' 'vegetarian']
#  ['Milk, cottage cheese, sugar' 'vegetarian']
#  ['Milk, rice, sugar, dried fruits' 'vegetarian']
#  ['Gram flour, ghee, sugar' 'vegetarian']
#  ['Yogurt, milk, nuts, sugar' 'vegetarian']
#  ['Refined flour, besan, ghee, powdered sugar, yoghurt, green cardamom'
#   'vegetarian']
#  ['Firm white pumpkin, sugar, kitchen lime, alum powder' 'vegetarian']
#  ['Rice, sugar, nuts' 'vegetarian']
#  ['Condensed milk, sugar, spices, nuts' 'vegetarian']
#  ['Semolina, ghee, nuts, milk' 'vegetarian']
#  ['Khoa, coconut, molu leaf' 'vegetarian']
#  ['Corn flour, ghee, dry fruits' 'vegetarian']
#  ['Gram flour, ghee, sugar, milk, cardamom' 'vegetarian']
#  ['Chhena, sugar, ghee' 'vegetarian']
#  ['Chhena, sugar, milk' 'vegetarian']
#  ['Sugar, chenna cheese' 'vegetarian']
#  ['Flour, cream, sugar, saffron, lemon juice, coconut flakes'
#   'vegetarian']
#  ['Chenna, condensed milk, sugar, saffron, cardamom' 'vegetarian']
#  ['Chhena, sugar, ghee' 'vegetarian']
#  ['Flour, fried milk power, sugar syrup' 'vegetarian']
#  ['Yoghurt, refined flour, ghee, fennel seeds' 'vegetarian']
#  ['Besan flour, sugar, ghee' 'vegetarian']
#  ['Milk, jaggery' 'vegetarian']
#  ['Chhena, sugar, ghee, flour' 'vegetarian']
#  ['Rice flour, wheat flour' 'vegetarian']
#  ['Chenna, sweetened milk' 'vegetarian']
#  ['Chhena, reduced milk, pistachio' 'vegetarian']
#  ['Chhena, sugar, cardamom' 'vegetarian']
#  ['Milk, sugar, saffron, cardamom' 'vegetarian']
#  ['Rice flour, jaggery, ghee, vegetable oil, elachi' 'vegetarian']
#  ['Rice flour, jaggery, ghee' 'vegetarian']
#  ['Besan, jaggery, cardamom powder, ghee, cashews and raisins, jaggery syrup, sugar'
#   'vegetarian']
#  ['Peanuts, jaggery' 'vegetarian']
#  ['Milk, Sugar, Dharwadi buffalo milk' 'vegetarian']
#  ['Loaf bread, milk' 'vegetarian']
#  ['Rice flour, sugar, salt, ghee, semolina' 'vegetarian']
#  ['Wheat flour, sugar' 'vegetarian']
#  ['Black lentils, rice' 'vegetarian']
#  ['Besan flour, semolina, mung bean, jaggery, coconut, skimmed milk powder, sugar, ghee'
#   'vegetarian']
#  ['Maida flour, turmeric, coconut, chickpeas, jaggery, ghee, cardamom'
#   'vegetarian']
#  ['Rice flour, milk' 'vegetarian']
#  ['Chana dal, jaggery' 'vegetarian']
#  ['Rice, jaggery, cashews, ghee' 'vegetarian']
#  ['Rice flour, powdered sugar, ghee' 'vegetarian']
#  ['Apricots, sugar syrup' 'vegetarian']
#  ['Vermicelli pudding, milk' 'vegetarian']
#  ['Rice flour, banana, jaggery, coconut' 'vegetarian']
#  ['Rice flour, jaggery, coconut' 'vegetarian']
#  ['Rice flour, jaggery, khus-khus seeds' 'vegetarian']
#  ['Sugar, milk, nuts' 'vegetarian']
#  ['Cucumber, rava' 'vegetarian']
#  ['Milk, rice, sugar, dry fruits' 'vegetarian']
#  ['Semolina, sugar' 'vegetarian']
#  ['Rice flour, coconut, jaggery ' 'vegetarian']
#  ['Sugar, ghee, maida flour, semolina' 'vegetarian']
#  ['Curd, sugar, saffron, cardamom' 'vegetarian']
#  ['Maida, sugar, ghee' 'vegetarian']
#  ['Fish, potol, tomato, chillies, ginger, garlic' 'non vegetarian']
#  ['Boiled pork, onions, chillies, ginger and garlic' 'non vegetarian']
#  ['Rice, milk, sugar, cardamom' 'vegetarian']
#  ['Rice, axone, salt, water, chillies, pork' 'non vegetarian']
#  ['Cauliflower, potato, garam masala, turmeric, curry leaves'
#   'vegetarian']
#  ['Rice flour, potato, bread crumbs, garam masala, salt' 'vegetarian']
#  ['Potato, peas, chillies, ginger, garam masala, garlic' 'vegetarian']
#  ['Potato, fenugreek leaves, chillies, salt, oil' 'vegetarian']
#  ['Potato, shimla mirch, garam masala, amchur powder, salt' 'vegetarian']
#  ['Chole, rava, yogurt, plain flour, baking soda' 'vegetarian']
#  ['Ladies finger, garam masala, kasuri methi, tomatoes, chili powder'
#   'vegetarian']
#  ['Chicken thighs, basmati rice, star anise, sweet, green chillies'
#   'non vegetarian']
#  ['Chicken, greek yogurt, cream, garam masala powder, cashew nuts, butter'
#   'non vegetarian']
#  ['Chickpeas, tomato paste, garam masala, ginger, red onion, avocado oil'
#   'vegetarian']
#  ['Whole wheat flour, olive oil, hot water, all purpose flour'
#   'vegetarian']
#  ['Chicken, dahi, sesame seeds, garam masala powder, cashew nuts, saffron'
#   'non vegetarian']
#  ['Naan bread, tomato sauce, skinless chicken breasts, heavy cream, garam masala'
#   'non vegetarian']
#  ['Chicken, whole wheat bread, rice flour, garam masala powder, whole egg'
#   'non vegetarian']
#  ['Chole, bhatura, garam masala, bay leaf, cinnamon stick' 'vegetarian']
#  ['Moong dal, masoor dal, chana dal, wheat flour, almond' 'vegetarian']
#  ['Moong dal, garam masala powder, garlic, green chilli, all purpose flour'
#   'vegetarian']
#  ['Red kidney beans, urad dal, cream, garam masala, chili powder'
#   'vegetarian']
#  ['Pigeon peas, garam masala, ginger, red onion, kasuri methi'
#   'vegetarian']
#  ['Baby potatoes, garam masala, cashew nuts, kasuri methi, tomatoes'
#   'vegetarian']
#  ['Beaten rice flakes, potato, curry leaves, green chilies, lemon juice'
#   'vegetarian']
#  ['Chana dal, whole wheat flour, arhar dal, white urad dal, garam masala powder'
#   'vegetarian']
#  ['Moong dal, rava, garam masala, dough, fennel seeds' 'vegetarian']
#  ['Cottage cheese, bell peppers, gravy, garam masala, cashew nuts'
#   'vegetarian']
#  ['Besan, garam masala powder, gram flour, ginger, curry leaves'
#   'vegetarian']
#  ['Bitter gourd, fennel, garam masala powder, chili powder, amchur powder'
#   'vegetarian']
#  ['Moong dal, green peas, ginger, tomato, green chili' 'vegetarian']
#  ['Paneer, potato, cream, corn flour, garam masala' 'vegetarian']
#  ['Rose syrup, falooda sev, mixed nuts, saffron, sugar' 'vegetarian']
#  ['Bottle gourd, garam masala powder, gram flour, ginger, chillies'
#   'vegetarian']
#  ['Bottle gourd, coconut oil, garam masala, ginger, green chillies'
#   'vegetarian']
#  ['Wheat flour, roasted gram flour, tomato, nigella seeds, chilli'
#   'vegetarian']
#  ['Palak, makki atta, mustard green, garam masala, ginger' 'vegetarian']
#  ['Whole wheat flour, chickpea flour, green chilies' 'vegetarian']
#  ['Mushroom, malai, garam masala, ginger, capsicum' 'vegetarian']
#  ['Canned coconut milk, frozen green peas, wild mushrooms, garam masala, tomatoes'
#   'vegetarian']
#  ['Whole wheat flour, honey, butter, garlic' 'vegetarian']
#  ['Green beans, potatoes, khus khus, low fat, garam masala powder'
#   'vegetarian']
#  ['Cottage cheese, palak, cream, garam masala, butter' 'vegetarian']
#  ['Paneer, whipping cream, garam masala, cashew nuts, butter'
#   'vegetarian']
#  ['Paneer, greek yogurt, tandoori masala, cream, bell pepper'
#   'vegetarian']
#  ['Kala chana, mashed potato, boondi, sev, lemon' 'vegetarian']
#  ['Whole wheat flour, musk melon seeds, poppy seeds, edible gum, semolina'
#   'vegetarian']
#  ['Urad dal, sev, lemon juice, chopped tomatoes' 'vegetarian']
#  ['Wheat flour, butter, potato, coriander' 'vegetarian']
#  ['Arbi ke patte, sesame seeds, gur, bengal gram flour, imli'
#   'vegetarian']
#  ['Fennel, tea bags, tomato, kasuri methi, cinnamon' 'vegetarian']
#  ['Red kidney beans, garam masala powder, ginger, tomato, mustard oil'
#   'vegetarian']
#  ['Garam masala powder, tomato, kasuri methi, cinnamon, mustard oil'
#   'vegetarian']
#  ['Potatoes, green peas, garam masala, ginger, dough' 'vegetarian']
#  ['Sattu, atta, dough, filling, mustard oil' 'vegetarian']
#  ['Cottage cheese, malai, garam masala, ginger, tomato' 'vegetarian']
#  ['Rose water, milk, white bread slices, saffron, almonds' 'vegetarian']
#  ['Baby corn, french beans, garam masala, ginger, carrot' 'vegetarian']
#  ['Greek yogurt, garam masala, kasuri methi, marinade, mustard oil'
#   'non vegetarian']
#  ['Chickpea flour, biryani masala powder, yogurt, fish fillets, green bell pepper'
#   'non vegetarian']
#  ['Whole wheat flour, arhar dal, ginger, kala jeera, green chilli'
#   'vegetarian']
#  ['Raw banana, elephant foot yam, long beans, tindora, urad dal'
#   'vegetarian']
#  ['Split pigeon peas, chana dal, urad dal, green peas, french beans'
#   'vegetarian']
#  ['Chana dal, urad dal, fresh coconut, sesame seeds, curry leaves'
#   'vegetarian']
#  ['Chana dal, urad dal, whole urad dal, blend rice, rock salt'
#   'vegetarian']
#  ['Rice flour, hot water, grated coconut' 'vegetarian']
#  ['Split urad dal, urad dal, idli rice, thick poha, rock salt'
#   'vegetarian']
#  ['Carrot, yellow mustard, red chilli, black salt' 'vegetarian']
#  ['Sesame oil, drumstick, tamarind paste, sambar powder, tomato'
#   'vegetarian']
#  ['Moong dal, chana dal, spinach, urad dal, coconut oil' 'vegetarian']
#  ['Urad dal, curry leaves, sugar, mustard seeds, spinach' 'vegetarian']
#  ['Greens, tomato, mustard seeds, fenugreek seeds' 'vegetarian']
#  ['Amaranth leaves, split urad dal, mustard seeds, grated coconut, red chili'
#   'vegetarian']
#  ['Beef, coconut, garam masala, curry leaves, green chilies, chili powder'
#   'non vegetarian']
#  ['Chana dal, urad dal, potato, beans, peas' 'vegetarian']
#  ['Moong dal, chana dal, cabbage, tamarind, curry leaves' 'vegetarian']
#  ['Moong dal, cucumber, curry leaves, green chili, lemon juice'
#   'vegetarian']
#  ['Chana dal, urad dal, gooseberry, raw rice, curry leaves' 'vegetarian']
#  ['Sesame oil, raw rice, jaggery, grated coconut' 'vegetarian']
#  ['Pearl onions, urad dal, drumsticks, tomato, curry leaves' 'vegetarian']
#  ['Chana dal, urad dal, potatoes, idli rice, thick poha' 'vegetarian']
#  ['Coconut oil, cucumber, curd, curry leaves, mustard seeds' 'vegetarian']
#  ['Yogurt, ginger, curry leaves, baking soda, green chilli' 'vegetarian']
#  ['Lentils, black pepper, vegetable oil' 'vegetarian']
#  ['Raw rice,  jaggery, milk' 'vegetarian']
#  ['Rice, cashew nuts, milk, raisins, sugar' 'vegetarian']
#  ['Arhar dal, sambar powder, tomato, curry leaves, fennel seeds'
#   'vegetarian']
#  ['Green moong beans, rice flour' 'vegetarian']
#  ['Chana dal, urad dal, beans, coconut, mustard' 'vegetarian']
#  ['Urad dal, lemon, tamarind, cooked rice, curry leaves' 'vegetarian']
#  ['Tomato, curry leaves, garlic, mustard seeds, hot water' 'vegetarian']
#  ['Brown rice flour, sugar, grated coconut' 'vegetarian']
#  ['Pigeon peas, eggplant, drumsticks, sambar powder, tamarind'
#   'vegetarian']
#  ['Thin rice flakes, black sesame seeds, curry leaves' 'vegetarian']
#  ['Sevai, parboiled rice, steamer' 'vegetarian']
#  ['Urad dal, curd, sesame oil, ginger, curry leaves, mustard seeds'
#   'vegetarian']
#  ['Coconut, whole red beans, masala, sesame oil, tamarind' 'vegetarian']
#  ['Chana dal, urad dal, thick poha, tomato, butter' 'vegetarian']
#  ['Urad dal, ginger, curry leaves, green chilies, black pepper'
#   'vegetarian']
#  ['Meat curry powder, chicken chunks, ginger, tomato, cinnamon'
#   'non vegetarian']
#  ['Chana dal, urad dal, ginger, curry leaves, sugar' 'vegetarian']
#  ['Kala masala, arhar dal, curry leaves, mustard seeds, hot water'
#   'vegetarian']
#  ['Gram flour, mustard, garlic, turmeric, red chilli' 'vegetarian']
#  ['Baingan, fish, coconut oil, fresh coconut, ginger' 'non vegetarian']
#  ['Urad dal, potatoes, wheat flour, sooji' 'vegetarian']
#  ['Wheat flour, pearl millet flour, hot water' 'vegetarian']
#  ['Condensed milk, mawa, desiccated coconut, almonds, cashews'
#   'vegetarian']
#  ['Jowar flour, sesame seeds' 'vegetarian']
#  ['Bombay duck, malvani masala, rice flour, bombay rava, green chilies'
#   'non vegetarian']
#  ['Rice flour, sesame, plain flour, turmeric, red chilli' 'vegetarian']
#  ['Citric acid, fry, raisins, sugar, chana daal' 'vegetarian']
#  ['Urad dal, bengal gram flour, dried mango, baking soda, black salt'
#   'vegetarian']
#  ['Condensed milk, nestle cream, coconut ice, red food coloring, desiccated coconut'
#   'vegetarian']
#  ['Whole wheat flour, dal, kokum, gur, bengal gram flour' 'vegetarian']
#  ['Pav, aloo, peanut, pomegranate, star anise' 'vegetarian']
#  ['Urad dal, bhuna chana, garam masala, dates, tamarind' 'vegetarian']
#  ['Arhar dal, coconut oil, curry leaves, mustard seeds, red chilli'
#   'vegetarian']
#  ['Rava, coconut, gram flour, mustard, sesame' 'vegetarian']
#  ['Bottle gourd, green, raisins, sugar, clarified butter' 'vegetarian']
#  ['Yogurt, besan, sauce, garam masala powder, gram flour' 'vegetarian']
#  ['Wheat flour, jaggery, clarified butter, sliced almonds' 'vegetarian']
#  ['Dry fruits, semolina, all purpose flour' 'vegetarian']
#  ['Bottle gourd, chana dal, cabbage, urad dal, toor dal' 'vegetarian']
#  ['Whole wheat rava, chia seed, lemon, edible gum, litre milk'
#   'vegetarian']
#  ['Green chilies, lemon juice, chili powder, boiled potatoes'
#   'vegetarian']
#  ['Wheat flour, cashews, rapeseed oil' 'vegetarian']
#  ['Mango, sugar' 'vegetarian']
#  ['Whole wheat flour, low fat, bengal gram flour' 'vegetarian']
#  ['Green chili paste, white sesame seeds, gram flour, curry leaves, green chili'
#   'vegetarian']
#  ['Rice flour, urad dal, wheat flour, gram flour, turmeric' 'vegetarian']
#  ['Cinnamon, jaggery, clarified butter, dry roasted' 'vegetarian']
#  ['Cucumber, carrot, tomatoes, cilantro' 'vegetarian']
#  ['Rava, gram flour, lemon juice, turmeric, fenugreek leaves'
#   'vegetarian']
#  ['Rose water, pistachio, badam, bengal gram flour, saffron' 'vegetarian']
#  ['Bottle gourd, whole wheat flour, rava, sesame seeds, bengal gram flour'
#   'vegetarian']
#  ['Arbi ke patte, sesame seeds, gur, bengal gram flour, imli'
#   'vegetarian']
#  ['Pav bhaji masala, gobi, potatoes, green peas, dinner rolls'
#   'vegetarian']
#  ['Aloo, urad dal, mustard, ginger, curry leaves' 'vegetarian']
#  ['Raw peanuts, sabudana, lemon, avocado oil, curry leaves, green chili'
#   'vegetarian']
#  ['Khaman, pomegranate, sev, powdered sugar, garlic' 'vegetarian']
#  ['Sev, ginger, tomato, sugar' 'vegetarian']
#  ['Wheat flour, baking soda, all purpose flour, black pepper, sunflower oil'
#   'vegetarian']
#  ['Whole wheat flour, gur, clarified butter' 'vegetarian']
#  ['Rice flakes, yogurt, raw rice, jaggery, grated coconut' 'vegetarian']
#  ['Whole wheat flour, rice flour, pearl millet flour, sorghum flour, sesame seeds'
#   'vegetarian']
#  ['Sweet potato, surti papdi, baby potatoes, valor papdi, green peas'
#   'vegetarian']
#  ['Gobi, potato, beans, khus khus, coconut' 'vegetarian']
#  ['Chicken, coconut oil, wine vinegar, ginger, green, cinnamon'
#   'non vegetarian']
#  ['Green garlic chutney, fresh green peas, ginger, lemon juice, plain flour'
#   'vegetarian']
#  ['Moong beans, jaggery, red chillies, oil, salt' 'vegetarian']
#  ['Rice flour, sesame seeds, baking soda, peanut oil' 'vegetarian']
#  ['Chickpea flour, methi leaves, jowar flour, wheat flour' 'vegetarian']
#  ['Semolina, clarified butter, oil, white flour, black pepper'
#   'vegetarian']
#  ['Yogurt, fresh coconut, sesame seeds, semolina, gram flour'
#   'vegetarian']
#  ['Ridge gourd, baking soda, sugar, grated coconut, peas' 'vegetarian']
#  ['Whole wheat flour, khus khus, sesame seeds, dry coconut, gur'
#   'vegetarian']
#  ['Rice, mango, curd' 'vegetarian']
#  ['Sticky rice, rice flour, jaggery, orange rind' 'vegetarian']
#  ['Raw papaya, panch phoran masala, nigella seeds, mustard oil, fennel seeds'
#   'vegetarian']
#  ['Rice, eggs, carrot, beetroot' 'non vegetarian']
#  ['Maida, vegetable oil' 'vegetarian']
#  ['Potatoes, mustard oil, fish, green chillies' 'non vegetarian']
#  ['Ridge gourd, fish, lemon, tomatoes, mustard oil' 'non vegetarian']
#  ['Brinjal, onions, salt, sesame seeds, coriander' 'vegetarian']
#  ['Potatoes, garam masala, tomatoes, mustard oil, bay leaf'
#   'non vegetarian']
#  ['Forbidden black rice, chicken, olive oil, slivered almonds, garlic powder'
#   'non vegetarian']
#  ['Biryani masala, mixed vegetables, yellow moong daal, whole red, mustard seeds'
#   'vegetarian']
#  ['Brown rice, soy sauce, olive oil' 'vegetarian']
#  ['Coconut milk, lobster, fresh green chilli, ginger, red onion'
#   'non vegetarian']
#  ['Baking soda, clarified butter, oil, all purpose flour' 'vegetarian']
#  ['Jaggery, raisins' 'vegetarian']
#  ['Lamb, garam masala powder, curd, turmeric, bay leaf' 'non vegetarian']
#  ['Coconut, prawns, curd, mustard seed, green chili' 'non vegetarian']
#  ['Fish fillet, besan, lemon, mint, ginger' 'non vegetarian']
#  ['Fermented bamboo shoot, potato, ginger, green, mustard oil'
#   'vegetarian']
#  ['Banana flower, chicken, green chili, mustard oil, lemon juice'
#   'non vegetarian']
#  ['Aloo, tomatoes, mustard oil, bay leaf, cinnamon stick'
#   'non vegetarian']
#  ['Rice flour, mutton, banana, gram flour, olive oil, baking powder'
#   'non vegetarian']
#  ['Fish roe, pumpkin flowers, mustard oil, turmeric, tomato'
#   'non vegetarian']
#  ['Chana dal, fresh coconut, ginger, cinnamon, raisins' 'vegetarian']
#  ['Curd, cooked rice, curry leaves, dry chilli' 'vegetarian']
#  ['Tea leaves, white sesame seeds, dry coconut, soaked rice' 'vegetarian']
#  ['Basmati rice, rose water, sugar, clarified butter, cardamom pods'
#   'vegetarian']
#  ['Coconut milk, prawns, garlic, turmeric, sugar' 'non vegetarian']
#  ['Red pepper, red onion, butter, watercress, olive oil' 'vegetarian']
#  ['Green beans, bitter gourd, ridge gourd, banana, brinjal' 'vegetarian']
#  ['Glutinous rice, black sesame seeds, gur' 'vegetarian']
#  ['Coconut milk, egg yolks, clarified butter, all purpose flour'
#   'vegetarian']
#  ['Cottage cheese, dry dates, dried rose petals, pistachio, badam'
#   'vegetarian']
#  ['Milk powder, dry fruits, arrowroot powder, all purpose flour'
#   'vegetarian']
#  ['Brown rice, fennel seeds, grated coconut, black pepper, ginger powder'
#   'vegetarian']]
